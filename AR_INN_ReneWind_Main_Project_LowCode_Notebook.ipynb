# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ## Business Context

# %% [markdown]
# Renewable energy sources play an increasingly important role in the global energy mix, as the effort to reduce the environmental impact of energy production increases.
#
# Out of all the renewable energy alternatives, wind energy is one of the most developed technologies worldwide. The U.S Department of Energy has put together a guide to achieving operational efficiency using predictive maintenance practices.
#
# Predictive maintenance uses sensor information and analysis methods to measure and predict degradation and future component capability. The idea behind predictive maintenance is that failure patterns are predictable and if component failure can be predicted accurately and the component is replaced before it fails, the costs of operation and maintenance will be much lower.
#
# The sensors fitted across different machines involved in the process of energy generation collect data related to various environmental factors (temperature, humidity, wind speed, etc.) and additional features related to various parts of the wind turbine (gearbox, tower, blades, break, etc.).

# %% [markdown]
# ## Objective

# %% [markdown]
# “ReneWind” is a company working on improving the machinery/processes involved in the production of wind energy using machine learning and has collected data of generator failure of wind turbines using sensors. They have shared a ciphered version of the data, as the data collected through sensors is confidential (the type of data collected varies with companies). Data has 40 predictors, 20000 observations in the training set and 5000 in the test set.
#
# The objective is to build various classification models, tune them, and find the best one that will help identify failures so that the generators could be repaired before failing/breaking to reduce the overall maintenance cost.
# The nature of predictions made by the classification model will translate as follows:
#
# - True positives (TP) are failures correctly predicted by the model. These will result in repairing costs.
# - False negatives (FN) are real failures where there is no detection by the model. These will result in replacement costs.
# - False positives (FP) are detections where there is no failure. These will result in inspection costs.
#
# It is given that the cost of repairing a generator is much less than the cost of replacing it, and the cost of inspection is less than the cost of repair.
#
# “1” in the target variables should be considered as “failure” and “0” represents “No failure”.

# %% [markdown]
# ## Data Description

# %% [markdown]
# The data provided is a transformed version of the original data which was collected using sensors.
#
# - Train.csv - To be used for training and tuning of models.
# - Test.csv - To be used only for testing the performance of the final best model.
#
# Both the datasets consist of 40 predictor variables and 1 target variable.

# %% [markdown]
# # **Please read the instructions carefully before starting the project.**
# This is a commented Jupyter IPython Notebook file in which all the instructions and tasks to be performed are mentioned.
# * Blanks '_______' are provided in the notebook that
# needs to be filled with an appropriate code to get the correct result. With every '_______' blank, there is a comment that briefly describes what needs to be filled in the blank space.
# * Identify the task to be performed correctly, and only then proceed to write the required code.
# * Fill the code wherever asked by the commented lines like "# write your code here" or "# complete the code". Running incomplete code may throw error.
# * Please run the codes in a sequential manner from the beginning to avoid any unnecessary errors.
# * Add the results/observations (wherever mentioned) derived from the analysis in the presentation and submit the same.

# %% [markdown]
# # **Installing and Importing the necessary libraries**

# %%
# Installing the libraries with the specified version
# !pip install --no-deps tensorflow==2.18.0 scikit-learn==1.3.2 matplotlib===3.8.3 seaborn==0.13.2 numpy==1.26.4 pandas==2.2.2 -q --user --no-warn-script-location

# %% [markdown]
# **Note**:
# - After running the above cell, kindly restart the runtime (for Google Colab) or notebook kernel (for Jupyter Notebook), and run all cells sequentially from the next cell.
# - On executing the above line of code, you might see a warning regarding package dependencies. This error message can be ignored as the above code ensures that all necessary libraries and their dependencies are maintained to successfully execute the code in ***this notebook***.

# %%
# Library for data manipulation and analysis.
import pandas as pd
# Fundamental package for scientific computing.
import numpy as np
#splitting datasets into training and testing sets.
from sklearn.model_selection import train_test_split
#Imports tools for data preprocessing including label encoding, one-hot encoding, and standard scaling
from sklearn.preprocessing import LabelEncoder, OneHotEncoder,StandardScaler
#Imports a class for imputing missing values in datasets.
from sklearn.impute import SimpleImputer
#Imports the Matplotlib library for creating visualizations.
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# Imports the Seaborn library for statistical data visualization.
import seaborn as sns
# Time related functions.
import time
#Imports functions for evaluating the performance of machine learning models
from sklearn.metrics import confusion_matrix, f1_score,accuracy_score, recall_score, precision_score, classification_report
#Imports metrics from
from sklearn import metrics

#Imports the tensorflow,keras and layers.
import tensorflow
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dense, Input, Dropout,BatchNormalization
from tensorflow.keras import backend

# to suppress unnecessary warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Loading the Data**

# %%
# uncomment and run the following lines for Google Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Train.csv")    # Complete the code to import the training data
df_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Test.csv")    # Complete the code to import the test data

# %% [markdown]
# # **Data Overview**

# %% [markdown]
# The initial steps to get an overview of any dataset is to:
# - observe the first few rows of the dataset, to check whether the dataset has been loaded properly or not
# - get information about the number of rows and columns in the dataset
# - find out the data types of the columns to ensure that data is stored in the preferred format and the value of each property is as expected.
# - check the statistical summary of the dataset to get an overview of the numerical columns of the data

# %% [markdown]
# ## Checking the shape of the dataset

# %%
# Checking the number of rows and columns in the training data
df.shape # Complete the code to print the shape of the train data
# Out:
# (20000, 41)

# %%
# Checking the number of rows and columns in the test data
df_test.shape # Complete the code to print the shape of the test data
# Out:
# (5000, 41)

# %%
# let's create a copy of the training data
data = df.copy()

# %%
# let's create a copy of the testing  data
data_test = df_test.copy()

# %% [markdown]
# ## Displaying the first few rows of the dataset

# %%
# let's view the first 5 rows of the data
data.head() # Complete the code to view the first five rows of the train data
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -4.464606 -4.679129  3.101546  0.506130 -0.221083 -2.032511 -2.910870
# 1  3.365912  3.653381  0.909671 -1.367528  0.332016  2.358938  0.732600
# 2 -3.831843 -5.824444  0.634031 -2.418815 -1.773827  1.016824 -2.098941
# 3  1.618098  1.888342  7.046143 -1.147285  0.083080 -1.529780  0.207309
# 4 -0.111440  3.872488 -3.758361 -2.982897  3.792714  0.544960  0.205433
#
#          V8        V9       V10  ...       V32       V33        V34       V35  \
# 0  0.050714 -1.522351  3.761892  ...  3.059700 -1.690440   2.846296  2.235198
# 1 -4.332135  0.565695 -0.101080  ... -1.795474  3.032780  -2.467514  1.894599
# 2 -3.173204 -2.081860  5.392621  ... -0.257101  0.803550   4.086219  2.292138
# 3 -2.493629  0.344926  2.118578  ... -3.584425 -2.577474   1.363769  0.622714
# 4  4.848994 -1.854920 -6.220023  ...  8.265896  6.629213 -10.068689  1.222987
#
#         V36       V37       V38       V39       V40  Target
# 0  6.667486  0.443809 -2.369169  2.950578 -3.480324       0
# 1 -2.297780 -1.731048  5.908837 -0.386345  0.616242       0
# 2  5.360850  0.351993  2.940021  3.839160 -4.309402       0
# 3  5.550100 -1.526796  0.138853  3.101430 -1.277378       0
# 4 -3.229763  1.686909 -2.163896 -3.644622  6.510338       0
#
# [5 rows x 41 columns]

# %%
#viewing first 5 rows of the test data
data_test.head() # Complete the code to view the first five rows of the test data
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -0.613489 -3.819640  2.202302  1.300420 -1.184929 -4.495964 -1.835817
# 1  0.389608 -0.512341  0.527053 -2.576776 -1.016766  2.235112 -0.441301
# 2 -0.874861 -0.640632  4.084202 -1.590454  0.525855 -1.957592 -0.695367
# 3  0.238384  1.458607  4.014528  2.534478  1.196987 -3.117330 -0.924035
# 4  5.828225  2.768260 -1.234530  2.809264 -1.641648 -1.406698  0.568643
#
#          V8        V9       V10  ...       V32       V33       V34       V35  \
# 0  4.722989  1.206140 -0.341909  ...  2.291204 -5.411388  0.870073  0.574479
# 1 -4.405744 -0.332869  1.966794  ... -2.474936  2.493582  0.315165  2.059288
# 2  1.347309 -1.732348  0.466500  ... -1.318888 -2.997464  0.459664  0.619774
# 3  0.269493  1.322436  0.702345  ...  3.517918 -3.074085 -0.284220  0.954576
# 4  0.965043  1.918379 -2.774855  ...  1.773841 -1.501573 -2.226702  4.776830
#
#         V36       V37        V38       V39       V40  Target
# 0  4.157191  1.428093 -10.511342  0.454664 -1.448363       0
# 1  0.683859 -0.485452   5.128350  1.720744 -1.488235       0
# 2  5.631504  1.323512  -1.752154  1.808302  1.675748       0
# 3  3.029331 -1.367198  -3.412140  0.906000 -2.450889       0
# 4 -6.559698 -0.805551  -0.276007 -3.858207 -0.537694       0
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Checking the data types of the columns in the dataset

# %%
# let's check the data types of the columns in the dataset
data.info() # Complete the code to view the data types of the columns in the train data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 41 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      19982 non-null  float64
#  1   V2      19982 non-null  float64
#  2   V3      20000 non-null  float64
#  3   V4      20000 non-null  float64
#  4   V5      20000 non-null  float64
#  5   V6      20000 non-null  float64
#  6   V7      20000 non-null  float64
#  7   V8      20000 non-null  float64
#  8   V9      20000 non-null  float64
#  9   V10     20000 non-null  float64
#  10  V11     20000 non-null  float64
#  11  V12     20000 non-null  float64
#  12  V13     20000 non-null  float64
#  13  V14     20000 non-null  float64
#  14  V15     20000 non-null  float64
#  15  V16     20000 non-null  float64
#  16  V17     20000 non-null  float64
#  17  V18     20000 non-null  float64
#  18  V19     20000 non-null  float64
#  19  V20     20000 non-null  float64
#  20  V21     20000 non-null  float64
#  21  V22     20000 non-null  float64
#  22  V23     20000 non-null  float64
#  23  V24     20000 non-null  float64
#  24  V25     20000 non-null  float64
#  25  V26     20000 non-null  float64
#  26  V27     20000 non-null  float64
#  27  V28     20000 non-null  float64
#  28  V29     20000 non-null  float64
#  29  V30     20000 non-null  float64
#  30  V31     20000 non-null  float64
#  31  V32     20000 non-null  float64
#  32  V33     20000 non-null  float64
#  33  V34     20000 non-null  float64
#  34  V35     20000 non-null  float64
#  35  V36     20000 non-null  float64
#  36  V37     20000 non-null  float64
#  37  V38     20000 non-null  float64
#  38  V39     20000 non-null  float64
#  39  V40     20000 non-null  float64
#  40  Target  20000 non-null  int64
# dtypes: float64(40), int64(1)
# memory usage: 6.3 MB

# %% [markdown]
# - Converting Target column to float

# %%
data['Target'] = data['Target'].astype(float)

# %% [markdown]
# Now checking for test data

# %%
data_test.info() # Complete the code to view the data types of the columns in the test data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 41 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      4995 non-null   float64
#  1   V2      4994 non-null   float64
#  2   V3      5000 non-null   float64
#  3   V4      5000 non-null   float64
#  4   V5      5000 non-null   float64
#  5   V6      5000 non-null   float64
#  6   V7      5000 non-null   float64
#  7   V8      5000 non-null   float64
#  8   V9      5000 non-null   float64
#  9   V10     5000 non-null   float64
#  10  V11     5000 non-null   float64
#  11  V12     5000 non-null   float64
#  12  V13     5000 non-null   float64
#  13  V14     5000 non-null   float64
#  14  V15     5000 non-null   float64
#  15  V16     5000 non-null   float64
#  16  V17     5000 non-null   float64
#  17  V18     5000 non-null   float64
#  18  V19     5000 non-null   float64
#  19  V20     5000 non-null   float64
#  20  V21     5000 non-null   float64
#  21  V22     5000 non-null   float64
#  22  V23     5000 non-null   float64
#  23  V24     5000 non-null   float64
#  24  V25     5000 non-null   float64
#  25  V26     5000 non-null   float64
#  26  V27     5000 non-null   float64
#  27  V28     5000 non-null   float64
#  28  V29     5000 non-null   float64
#  29  V30     5000 non-null   float64
#  30  V31     5000 non-null   float64
#  31  V32     5000 non-null   float64
#  32  V33     5000 non-null   float64
#  33  V34     5000 non-null   float64
#  34  V35     5000 non-null   float64
#  35  V36     5000 non-null   float64
#  36  V37     5000 non-null   float64
#  37  V38     5000 non-null   float64
#  38  V39     5000 non-null   float64
#  39  V40     5000 non-null   float64
#  40  Target  5000 non-null   int64
# dtypes: float64(40), int64(1)
# memory usage: 1.6 MB

# %% [markdown]
# Converting Target to float

# %%
data_test['Target'] = data_test['Target'].astype(float)

# %% [markdown]
# ## Checking for duplicate values

# %%
# let's check for duplicate values in the data
data.duplicated().sum() # Complete the code to check for duplicate values in the train data
# Out:
# np.int64(0)

# %% [markdown]
# ## Checking for missing values

# %%
# let's check for missing values in the data
data.isnull().sum()
# Out:
# V1        18
# V2        18
# V3         0
# V4         0
# V5         0
# V6         0
# V7         0
# V8         0
# V9         0
# V10        0
# V11        0
# V12        0
# V13        0
# V14        0
# V15        0
# V16        0
# V17        0
# V18        0
# V19        0
# V20        0
# V21        0
# V22        0
# V23        0
# V24        0
# V25        0
# V26        0
# V27        0
# V28        0
# V29        0
# V30        0
# V31        0
# V32        0
# V33        0
# V34        0
# V35        0
# V36        0
# V37        0
# V38        0
# V39        0
# V40        0
# Target     0
# dtype: int64

# %%
# let's check for missing values in the test data
data_test.isnull().sum() # Complete the code to check for missing values in the test data
# Out:
# V1        5
# V2        6
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# V29       0
# V30       0
# V31       0
# V32       0
# V33       0
# V34       0
# V35       0
# V36       0
# V37       0
# V38       0
# V39       0
# V40       0
# Target    0
# dtype: int64

# %% [markdown]
# ## Statistical summary of the dataset

# %%
# let's view the statistical summary of the numerical columns in the data
data.describe().T # Complete the code to view the statistical summary of the train data
# Out:
#           count      mean       std        min       25%       50%       75%  \
# V1      19982.0 -0.271996  3.441625 -11.876451 -2.737146 -0.747917  1.840112
# V2      19982.0  0.440430  3.150784 -12.319951 -1.640674  0.471536  2.543967
# V3      20000.0  2.484699  3.388963 -10.708139  0.206860  2.255786  4.566165
# V4      20000.0 -0.083152  3.431595 -15.082052 -2.347660 -0.135241  2.130615
# V5      20000.0 -0.053752  2.104801  -8.603361 -1.535607 -0.101952  1.340480
# V6      20000.0 -0.995443  2.040970 -10.227147 -2.347238 -1.000515  0.380330
# V7      20000.0 -0.879325  1.761626  -7.949681 -2.030926 -0.917179  0.223695
# V8      20000.0 -0.548195  3.295756 -15.657561 -2.642665 -0.389085  1.722965
# V9      20000.0 -0.016808  2.160568  -8.596313 -1.494973 -0.067597  1.409203
# V10     20000.0 -0.012998  2.193201  -9.853957 -1.411212  0.100973  1.477045
# V11     20000.0 -1.895393  3.124322 -14.832058 -3.922404 -1.921237  0.118906
# V12     20000.0  1.604825  2.930454 -12.948007 -0.396514  1.507841  3.571454
# V13     20000.0  1.580486  2.874658 -13.228247 -0.223545  1.637185  3.459886
# V14     20000.0 -0.950632  1.789651  -7.738593 -2.170741 -0.957163  0.270677
# V15     20000.0 -2.414993  3.354974 -16.416606 -4.415322 -2.382617 -0.359052
# V16     20000.0 -2.925225  4.221717 -20.374158 -5.634240 -2.682705 -0.095046
# V17     20000.0 -0.134261  3.345462 -14.091184 -2.215611 -0.014580  2.068751
# V18     20000.0  1.189347  2.592276 -11.643994 -0.403917  0.883398  2.571770
# V19     20000.0  1.181808  3.396925 -13.491784 -1.050168  1.279061  3.493299
# V20     20000.0  0.023608  3.669477 -13.922659 -2.432953  0.033415  2.512372
# V21     20000.0 -3.611252  3.567690 -17.956231 -5.930360 -3.532888 -1.265884
# V22     20000.0  0.951835  1.651547 -10.122095 -0.118127  0.974687  2.025594
# V23     20000.0 -0.366116  4.031860 -14.866128 -3.098756 -0.262093  2.451750
# V24     20000.0  1.134389  3.912069 -16.387147 -1.468062  0.969048  3.545975
# V25     20000.0 -0.002186  2.016740  -8.228266 -1.365178  0.025050  1.397112
# V26     20000.0  1.873785  3.435137 -11.834271 -0.337863  1.950531  4.130037
# V27     20000.0 -0.612413  4.368847 -14.904939 -3.652323 -0.884894  2.189177
# V28     20000.0 -0.883218  1.917713  -9.269489 -2.171218 -0.891073  0.375884
# V29     20000.0 -0.985625  2.684365 -12.579469 -2.787443 -1.176181  0.629773
# V30     20000.0 -0.015534  3.005258 -14.796047 -1.867114  0.184346  2.036229
# V31     20000.0  0.486842  3.461384 -13.722760 -1.817772  0.490304  2.730688
# V32     20000.0  0.303799  5.500400 -19.876502 -3.420469  0.052073  3.761722
# V33     20000.0  0.049825  3.575285 -16.898353 -2.242857 -0.066249  2.255134
# V34     20000.0 -0.462702  3.183841 -17.985094 -2.136984 -0.255008  1.436935
# V35     20000.0  2.229620  2.937102 -15.349803  0.336191  2.098633  4.064358
# V36     20000.0  1.514809  3.800860 -14.833178 -0.943809  1.566526  3.983939
# V37     20000.0  0.011316  1.788165  -5.478350 -1.255819 -0.128435  1.175533
# V38     20000.0 -0.344025  3.948147 -17.375002 -2.987638 -0.316849  2.279399
# V39     20000.0  0.890653  1.753054  -6.438880 -0.272250  0.919261  2.057540
# V40     20000.0 -0.875630  3.012155 -11.023935 -2.940193 -0.920806  1.119897
# Target  20000.0  0.055500  0.228959   0.000000  0.000000  0.000000  0.000000
#
#               max
# V1      15.493002
# V2      13.089269
# V3      17.090919
# V4      13.236381
# V5       8.133797
# V6       6.975847
# V7       8.006091
# V8      11.679495
# V9       8.137580
# V10      8.108472
# V11     11.826433
# V12     15.080698
# V13     15.419616
# V14      5.670664
# V15     12.246455
# V16     13.583212
# V17     16.756432
# V18     13.179863
# V19     13.237742
# V20     16.052339
# V21     13.840473
# V22      7.409856
# V23     14.458734
# V24     17.163291
# V25      8.223389
# V26     16.836410
# V27     17.560404
# V28      6.527643
# V29     10.722055
# V30     12.505812
# V31     17.255090
# V32     23.633187
# V33     16.692486
# V34     14.358213
# V35     15.291065
# V36     19.329576
# V37      7.467006
# V38     15.289923
# V39      7.759877
# V40     10.654265
# Target   1.000000

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# ## Univariate analysis

# %%
# function to plot a boxplot and a histogram along the same scale.


def histogram_boxplot(data, feature, figsize=(12, 7), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to the show density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax= ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %% [markdown]
# ### Variables V1 to V29

# %%
for feature in df.columns:
    histogram_boxplot(df, feature, figsize=(12, 7), kde=False, bins=None)

# %% [markdown]
# ### Checking the distrubution of Target variable

# %%
# For train data
df["Target"].value_counts(1)
# Out:
# Target
# 0    0.9445
# 1    0.0555
# Name: proportion, dtype: float64

# %%
# For test data
df_test["Target"].value_counts(1) # Complete the code to display the proportion of the target variable in the test data
# Out:
# Target
# 0    0.9436
# 1    0.0564
# Name: proportion, dtype: float64

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Correlation Check

# %%
cols_list = df.select_dtypes(include=np.number).columns.tolist()
cols_list.remove("Target")

plt.figure(figsize=(20, 20))
sns.heatmap(
    df[cols_list].corr(), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="seismic"
)
plt.show()

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# ## Data Preparation for Modeling

# %%
# Dividing train data into X and y
X = data.drop(columns = ["Target"] , axis=1) # Complete the code to remove the column named 'Target'
y = data["Target"] # Complete the code to select the column named 'Target'

# %% [markdown]
# **Since we already have a separate test set, we don't need to divide data into train, valiation and test**

# %%
# Splitting data into training and validation set:

X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.2, random_state=1, stratify=y # Complete the code to define the test size
)

# %%
# Checking the number of rows and columns in the X_train data
X_train.shape
# Out:
# (16000, 40)

# %%
# Checking the number of rows and columns in the X_val data
X_val.shape
# Out:
# (4000, 40)

# %%
# Dividing test data into X_test and y_test
X_test = data_test.drop(columns = ['Target'] , axis= 1) # Complete the code to remove the target column
y_test = data_test["Target"] # Complete the code to select the target column

# %%
# Checking the number of rows and columns in the X_test data
X_test.shape
# Out:
# (5000, 40)

# %% [markdown]
# ## Missing Value Imputation

# %% [markdown]
# - There were few missing values in V1 and V2, we will impute them using the median.
# - And to avoid data leakage we will impute missing values after splitting train data into train and validation sets.

# %%
imputer = SimpleImputer(strategy="median")

# %%
# Fit and transform the train data
X_train = pd.DataFrame(imputer.fit_transform(X_train), columns=X_train.columns)

# Transform the validation data
X_val = pd.DataFrame(imputer.transform(X_val), columns=X_train.columns)    # Complete the code to impute missing values in the validation set while accounting for data leakage

# Transform the test data
X_test = pd.DataFrame(imputer.transform(X_test), columns=X_train.columns)    # Complete the code to impute missing values in the test set while accounting for data leakage

# %%
# Checking that no column has missing values in train or test sets
print(X_train.isna().sum())
print("-" * 30)
print(X_val.isna().sum())
print("-" * 30)
print(X_test.isna().sum())
# Out:
# V1     0
# V2     0
# V3     0
# V4     0
# V5     0
# V6     0
# V7     0
# V8     0
# V9     0
# V10    0
# V11    0
# V12    0
# V13    0
# V14    0
# V15    0
# V16    0
# V17    0
# V18    0
# V19    0
# V20    0
# V21    0
# V22    0
# V23    0
# V24    0
# V25    0
# V26    0
# V27    0
# V28    0
# V29    0
# V30    0
# V31    0
# V32    0
# V33    0
# V34    0
# V35    0
# V36    0
# V37    0
# V38    0
# V39    0
# V40    0
# dtype: int64
# ------------------------------
# V1     0
# V2     0
# V3     0
# V4     0
# V5     0
# V6     0
# V7     0
# V8     0
# V9     0
# V10    0
# V11    0
# V12    0
# V13    0
# V14    0
# V15    0
# V16    0
# V17    0
# V18    0
# V19    0
# V20    0
# V21    0
# V22    0
# V23    0
# V24    0
# V25    0
# V26    0
# V27    0
# V28    0
# V29    0
# V30    0
# V31    0
# V32    0
# V33    0
# V34    0
# V35    0
# V36    0
# V37    0
# V38    0
# V39    0
# V40    0
# dtype: int64
# ------------------------------
# V1     0
# V2     0
# V3     0
# V4     0
# V5     0
# V6     0
# V7     0
# V8     0
# V9     0
# V10    0
# V11    0
# V12    0
# V13    0
# V14    0
# V15    0
# V16    0
# V17    0
# V18    0
# V19    0
# V20    0
# V21    0
# V22    0
# V23    0
# V24    0
# V25    0
# V26    0
# V27    0
# V28    0
# V29    0
# V30    0
# V31    0
# V32    0
# V33    0
# V34    0
# V35    0
# V36    0
# V37    0
# V38    0
# V39    0
# V40    0
# dtype: int64

# %%
y_train = y_train.to_numpy()
y_val = y_val.to_numpy()
y_test = y_test.to_numpy()

# %% [markdown]
# # **Model Building**

# %% [markdown]
# ## Model Evaluation Criterion

# %% [markdown]
# - Write down the metric of choice with rationale here

# %% [markdown]
# **We are now done with pre-processing and evaluation criterion, so let's start building the model.**

# %% [markdown]
# ## Utility Functions

# %%
def plot(history, name):
    """
    Function to plot loss/accuracy

    history: an object which stores the metrics and losses.
    name: can be one of Loss or Accuracy
    """
    fig, ax = plt.subplots() #Creating a subplot with figure and axes.
    plt.plot(history.history[name]) #Plotting the train accuracy or train loss
    plt.plot(history.history['val_'+name]) #Plotting the validation accuracy or validation loss

    plt.title('Model ' + name.capitalize()) #Defining the title of the plot.
    plt.ylabel(name.capitalize()) #Capitalizing the first letter.
    plt.xlabel('Epoch') #Defining the label for the x-axis.
    fig.legend(['Train', 'Validation'], loc="outside right upper") #Defining the legend, loc controls the position of the legend.

# %%
# defining a function to compute different metrics to check performance of a classification model built using statsmodels
def model_performance_classification(
    model, predictors, target, threshold=0.5
):
    """
    Function to compute different metrics to check classification model performance

    model: classifier
    predictors: independent variables
    target: dependent variable
    threshold: threshold for classifying the observation as class 1
    """

    # checking which probabilities are greater than threshold
    pred = model.predict(predictors) > threshold
    # pred_temp = model.predict(predictors) > threshold
    # # rounding off the above values to get classes
    # pred = np.round(pred_temp)

    acc = accuracy_score(target, pred)  # to compute Accuracy
    recall = recall_score(target, pred, average='macro')  # to compute Recall
    precision = precision_score(target, pred, average='macro')  # to compute Precision
    f1 = f1_score(target, pred, average='macro')  # to compute F1-score

    # creating a dataframe of metrics
    df_perf = pd.DataFrame(
        {"Accuracy": acc, "Recall": recall, "Precision": precision, "F1 Score": f1,}, index = [0]
    )

    return df_perf

# %% [markdown]
# ## Initial Model Building (Model 0)

# %% [markdown]
# - Let's start with a neural network consisting of
#   - just one hidden layer of 7 neurons respectively
#   - activation function of ReLU.
#   - SGD as the optimizer

# %%
# defining the batch size and # epochs upfront as we'll be using the same values for all models
epochs = 50    # Complete the code to enter the number of epochs to be used in all models
batch_size = 32    # Complete the code to enter the batch size to be used in all models

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
#Initializing the neural network
model_0 = Sequential()
model_0.add(Dense( 7 ,activation="relu",input_dim=X_train.shape[1])) # Complete the code to define the number of neurons and the activation function
model_0.add(Dense( 1 ,activation="sigmoid")) # Complete the code to define the number of neurons in the output layer

# %%
model_0.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 7)              │           287 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             8 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 295 (1.15 KB)
#  Trainable params: 295 (1.15 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.SGD()   # defining SGD as the optimizer to be used
# model_0.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
# model_0.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
model_0.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_0.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_0.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs)
end=time.time()
# Out:
# Epoch 1/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - Recall: 0.4932 - loss: 0.1815 - val_Recall: 0.5360 - val_loss: 0.1224
# Epoch 2/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.5777 - loss: 0.1158 - val_Recall: 0.5721 - val_loss: 0.1146
# Epoch 3/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.6081 - loss: 0.1066 - val_Recall: 0.5946 - val_loss: 0.1060
# Epoch 4/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - Recall: 0.6351 - loss: 0.1012 - val_Recall: 0.6036 - val_loss: 0.1024
# Epoch 5/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.6385 - loss: 0.0968 - val_Recall: 0.6351 - val_loss: 0.0987
# Epoch 6/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - Recall: 0.6633 - loss: 0.0926 - val_Recall: 0.6532 - val_loss: 0.0967
# Epoch 7/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.6768 - loss: 0.0889 - val_Recall: 0.6622 - val_loss: 0.0930
# Epoch 8/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.6824 - loss: 0.0853 - val_Recall: 0.7027 - val_loss: 0.0903
# Epoch 9/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.6892 - loss: 0.0818 - val_Recall: 0.7072 - val_loss: 0.0870
# Epoch 10/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7196 - loss: 0.0782 - val_Recall: 0.7342 - val_loss: 0.0847
# Epoch 11/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7342 - loss: 0.0751 - val_Recall: 0.7477 - val_loss: 0.0839
# Epoch 12/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.7477 - loss: 0.0726 - val_Recall: 0.7568 - val_loss: 0.0802
# Epoch 13/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.7556 - loss: 0.0701 - val_Recall: 0.7748 - val_loss: 0.0788
# Epoch 14/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.7635 - loss: 0.0681 - val_Recall: 0.7748 - val_loss: 0.0780
# Epoch 15/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7691 - loss: 0.0665 - val_Recall: 0.7793 - val_loss: 0.0766
# Epoch 16/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7736 - loss: 0.0646 - val_Recall: 0.7748 - val_loss: 0.0755
# Epoch 17/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7815 - loss: 0.0628 - val_Recall: 0.7928 - val_loss: 0.0745
# Epoch 18/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7849 - loss: 0.0615 - val_Recall: 0.7928 - val_loss: 0.0735
# Epoch 19/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.7872 - loss: 0.0606 - val_Recall: 0.8018 - val_loss: 0.0727
# Epoch 20/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7928 - loss: 0.0599 - val_Recall: 0.8018 - val_loss: 0.0721
# Epoch 21/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.7973 - loss: 0.0590 - val_Recall: 0.8018 - val_loss: 0.0717
# Epoch 22/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.7973 - loss: 0.0587 - val_Recall: 0.8018 - val_loss: 0.0711
# Epoch 23/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.7984 - loss: 0.0582 - val_Recall: 0.8063 - val_loss: 0.0712
# Epoch 24/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8041 - loss: 0.0580 - val_Recall: 0.8018 - val_loss: 0.0705
# Epoch 25/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7995 - loss: 0.0575 - val_Recall: 0.8108 - val_loss: 0.0704
# Epoch 26/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8086 - loss: 0.0572 - val_Recall: 0.8063 - val_loss: 0.0705
# Epoch 27/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8052 - loss: 0.0571 - val_Recall: 0.8063 - val_loss: 0.0702
# Epoch 28/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8063 - loss: 0.0570 - val_Recall: 0.8018 - val_loss: 0.0696
# Epoch 29/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8097 - loss: 0.0566 - val_Recall: 0.7973 - val_loss: 0.0691
# Epoch 30/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8086 - loss: 0.0563 - val_Recall: 0.8018 - val_loss: 0.0693
# Epoch 31/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8074 - loss: 0.0564 - val_Recall: 0.8063 - val_loss: 0.0689
# Epoch 32/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8097 - loss: 0.0562 - val_Recall: 0.8108 - val_loss: 0.0690
# Epoch 33/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8086 - loss: 0.0560 - val_Recall: 0.8063 - val_loss: 0.0686
# Epoch 34/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8097 - loss: 0.0559 - val_Recall: 0.8063 - val_loss: 0.0689
# Epoch 35/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8142 - loss: 0.0556 - val_Recall: 0.8018 - val_loss: 0.0689
# Epoch 36/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - Recall: 0.8097 - loss: 0.0556 - val_Recall: 0.8018 - val_loss: 0.0689
# Epoch 37/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - Recall: 0.8131 - loss: 0.0555 - val_Recall: 0.7883 - val_loss: 0.0688
# Epoch 38/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8119 - loss: 0.0553 - val_Recall: 0.7973 - val_loss: 0.0683
# Epoch 39/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8097 - loss: 0.0551 - val_Recall: 0.8108 - val_loss: 0.0695
# Epoch 40/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8119 - loss: 0.0552 - val_Recall: 0.8063 - val_loss: 0.0688
# Epoch 41/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8164 - loss: 0.0549 - val_Recall: 0.8018 - val_loss: 0.0682
# Epoch 42/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8131 - loss: 0.0550 - val_Recall: 0.8108 - val_loss: 0.0680
# Epoch 43/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8153 - loss: 0.0548 - val_Recall: 0.8108 - val_loss: 0.0682
# Epoch 44/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8176 - loss: 0.0547 - val_Recall: 0.8063 - val_loss: 0.0685
# Epoch 45/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8176 - loss: 0.0547 - val_Recall: 0.8063 - val_loss: 0.0684
# Epoch 46/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8142 - loss: 0.0545 - val_Recall: 0.8018 - val_loss: 0.0682
# Epoch 47/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8187 - loss: 0.0542 - val_Recall: 0.8018 - val_loss: 0.0682
# Epoch 48/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8164 - loss: 0.0544 - val_Recall: 0.8063 - val_loss: 0.0683
# Epoch 49/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8176 - loss: 0.0543 - val_Recall: 0.8108 - val_loss: 0.0683
# Epoch 50/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8176 - loss: 0.0543 - val_Recall: 0.8018 - val_loss: 0.0677

# %%
print("Time taken in seconds ",end-start)
# Out:
# Time taken in seconds  91.64800930023193

# %%
plot(history,'loss')

# %%
model_0_train_perf = model_performance_classification(model_0, X_train, y_train)
model_0_train_perf
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0  0.988187  0.906831   0.977934   0.93916

# %%
model_0_val_perf = model_performance_classification(model_0,X_val,y_val)
model_0_val_perf
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#    Accuracy   Recall  Precision  F1 Score
# 0   0.98675  0.89971   0.970166  0.931717

# %% [markdown]
# Let's check the classification reports.

# %%
y_train_pred_0 = model_0.predict(X_train)
y_val_pred_0 = model_0.predict(X_val)
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
print("Classification Report - Train data Model_0",end="\n\n")
cr_train_model_0 = classification_report(y_train,y_train_pred_0>0.5)
print(cr_train_model_0)
# Out:
# Classification Report - Train data Model_0
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99     15112
#          1.0       0.97      0.82      0.88       888
#
#     accuracy                           0.99     16000
#    macro avg       0.98      0.91      0.94     16000
# weighted avg       0.99      0.99      0.99     16000

# %%
print("Classification Report - Validation data Model_0",end="\n\n")
cr_val_model_0 = classification_report(y_val,y_val_pred_0>0.5)
print(cr_val_model_0)
# Out:
# Classification Report - Validation data Model_0
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      3778
#          1.0       0.95      0.80      0.87       222
#
#     accuracy                           0.99      4000
#    macro avg       0.97      0.90      0.93      4000
# weighted avg       0.99      0.99      0.99      4000

# %% [markdown]
# # **Model Performance Improvement**

# %% [markdown]
# ## Model 1

# %% [markdown]
# - Let's try adding another layer to see if we can improve our model's performance.

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
#Initializing the neural network
model_1 = Sequential()
model_1.add(Dense( 16 ,activation="relu",input_dim=X_train.shape[1])) # Complete the code to define the number of neurons and activation function
model_1.add(Dense( 8,activation="relu")) # Complete the code to define the number of neurons and activation function
model_1.add(Dense(1,activation="sigmoid")) # Complete the code to define the number of neurons in the output layer

# %%
model_1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 801 (3.13 KB)
#  Trainable params: 801 (3.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.SGD()   # defining SGD as the optimizer to be used
# model_1.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
# model_1.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
model_1.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_1.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_1.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs)
end=time.time()
# Out:
# Epoch 1/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - Recall: 0.3176 - loss: 0.1766 - val_Recall: 0.4640 - val_loss: 0.1204
# Epoch 2/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.4899 - loss: 0.1081 - val_Recall: 0.5901 - val_loss: 0.1039
# Epoch 3/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.5923 - loss: 0.0934 - val_Recall: 0.6441 - val_loss: 0.0940
# Epoch 4/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.6374 - loss: 0.0845 - val_Recall: 0.6892 - val_loss: 0.0894
# Epoch 5/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.6802 - loss: 0.0777 - val_Recall: 0.7523 - val_loss: 0.0850
# Epoch 6/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7275 - loss: 0.0726 - val_Recall: 0.7658 - val_loss: 0.0803
# Epoch 7/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7331 - loss: 0.0690 - val_Recall: 0.7793 - val_loss: 0.0775
# Epoch 8/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7624 - loss: 0.0659 - val_Recall: 0.7793 - val_loss: 0.0751
# Epoch 9/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - Recall: 0.7748 - loss: 0.0638 - val_Recall: 0.7793 - val_loss: 0.0731
# Epoch 10/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.7849 - loss: 0.0617 - val_Recall: 0.7928 - val_loss: 0.0710
# Epoch 11/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7995 - loss: 0.0600 - val_Recall: 0.7928 - val_loss: 0.0707
# Epoch 12/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8041 - loss: 0.0588 - val_Recall: 0.7928 - val_loss: 0.0699
# Epoch 13/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8063 - loss: 0.0575 - val_Recall: 0.7973 - val_loss: 0.0688
# Epoch 14/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8119 - loss: 0.0565 - val_Recall: 0.8018 - val_loss: 0.0676
# Epoch 15/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8131 - loss: 0.0558 - val_Recall: 0.8108 - val_loss: 0.0670
# Epoch 16/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8176 - loss: 0.0549 - val_Recall: 0.8198 - val_loss: 0.0673
# Epoch 17/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8187 - loss: 0.0542 - val_Recall: 0.8198 - val_loss: 0.0671
# Epoch 18/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8300 - loss: 0.0536 - val_Recall: 0.8153 - val_loss: 0.0658
# Epoch 19/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8277 - loss: 0.0529 - val_Recall: 0.8288 - val_loss: 0.0651
# Epoch 20/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8322 - loss: 0.0526 - val_Recall: 0.8198 - val_loss: 0.0651
# Epoch 21/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8300 - loss: 0.0519 - val_Recall: 0.8153 - val_loss: 0.0650
# Epoch 22/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8300 - loss: 0.0516 - val_Recall: 0.8333 - val_loss: 0.0656
# Epoch 23/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8356 - loss: 0.0512 - val_Recall: 0.8288 - val_loss: 0.0649
# Epoch 24/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8356 - loss: 0.0507 - val_Recall: 0.8153 - val_loss: 0.0642
# Epoch 25/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8345 - loss: 0.0502 - val_Recall: 0.8198 - val_loss: 0.0645
# Epoch 26/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - Recall: 0.8390 - loss: 0.0502 - val_Recall: 0.8198 - val_loss: 0.0636
# Epoch 27/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8401 - loss: 0.0496 - val_Recall: 0.8333 - val_loss: 0.0641
# Epoch 28/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8423 - loss: 0.0492 - val_Recall: 0.8243 - val_loss: 0.0632
# Epoch 29/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8356 - loss: 0.0489 - val_Recall: 0.8243 - val_loss: 0.0632
# Epoch 30/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8401 - loss: 0.0487 - val_Recall: 0.8198 - val_loss: 0.0633
# Epoch 31/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8446 - loss: 0.0483 - val_Recall: 0.8153 - val_loss: 0.0634
# Epoch 32/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8423 - loss: 0.0482 - val_Recall: 0.8288 - val_loss: 0.0632
# Epoch 33/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8480 - loss: 0.0477 - val_Recall: 0.8243 - val_loss: 0.0634
# Epoch 34/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8468 - loss: 0.0475 - val_Recall: 0.8243 - val_loss: 0.0623
# Epoch 35/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8457 - loss: 0.0473 - val_Recall: 0.8288 - val_loss: 0.0625
# Epoch 36/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8457 - loss: 0.0470 - val_Recall: 0.8288 - val_loss: 0.0631
# Epoch 37/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8435 - loss: 0.0468 - val_Recall: 0.8288 - val_loss: 0.0623
# Epoch 38/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8480 - loss: 0.0464 - val_Recall: 0.8333 - val_loss: 0.0619
# Epoch 39/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8536 - loss: 0.0463 - val_Recall: 0.8288 - val_loss: 0.0619
# Epoch 40/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8468 - loss: 0.0459 - val_Recall: 0.8333 - val_loss: 0.0624
# Epoch 41/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8514 - loss: 0.0460 - val_Recall: 0.8288 - val_loss: 0.0616
# Epoch 42/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8525 - loss: 0.0456 - val_Recall: 0.8333 - val_loss: 0.0618
# Epoch 43/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - Recall: 0.8514 - loss: 0.0453 - val_Recall: 0.8288 - val_loss: 0.0611
# Epoch 44/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8536 - loss: 0.0446 - val_Recall: 0.8288 - val_loss: 0.0613
# Epoch 45/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8547 - loss: 0.0448 - val_Recall: 0.8288 - val_loss: 0.0617
# Epoch 46/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8514 - loss: 0.0448 - val_Recall: 0.8288 - val_loss: 0.0615
# Epoch 47/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8536 - loss: 0.0443 - val_Recall: 0.8333 - val_loss: 0.0627
# Epoch 48/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8604 - loss: 0.0442 - val_Recall: 0.8288 - val_loss: 0.0618
# Epoch 49/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8491 - loss: 0.0440 - val_Recall: 0.8288 - val_loss: 0.0606
# Epoch 50/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8570 - loss: 0.0439 - val_Recall: 0.8333 - val_loss: 0.0610

# %%
print("Time taken in seconds ",end-start)
# Out:
# Time taken in seconds  91.73200631141663

# %%
plot(history,'loss')

# %%
model_1_train_perf = model_performance_classification(model_1,X_train,y_train)
model_1_train_perf
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0   0.99125  0.930711   0.984511  0.955826

# %%
model_1_val_perf = model_performance_classification(model_1,X_val,y_val)
model_1_val_perf
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0    0.9895  0.916005   0.981986  0.946262

# %%
y_train_pred_1 = model_1.predict(X_train)
y_val_pred_1 = model_1.predict(X_val)
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
print("Classification Report - Train data Model_1", end="\n\n")
cr_train_model_1 = classification_report(y_train,y_train_pred_1 > 0.5)
print(cr_train_model_1)
# Out:
# Classification Report - Train data Model_1
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00     15112
#          1.0       0.98      0.86      0.92       888
#
#     accuracy                           0.99     16000
#    macro avg       0.98      0.93      0.96     16000
# weighted avg       0.99      0.99      0.99     16000

# %%
print("Classification Report - Validation data Model_1", end="\n\n")
cr_val_model_1 = classification_report(y_val,y_val_pred_1 > 0.5)
print(cr_val_model_1)
# Out:
# Classification Report - Validation data Model_1
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      3778
#          1.0       0.97      0.83      0.90       222
#
#     accuracy                           0.99      4000
#    macro avg       0.98      0.92      0.95      4000
# weighted avg       0.99      0.99      0.99      4000

# %% [markdown]
# ## Model 2

# %% [markdown]
# To introduce Regularization in our model, let's set the dropout to 50% after adding the first hidden layer. This step will randomly drop 50% of the neurons before proceeding to the next layer, reducing overfitting.

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
#Initializing the neural network
from tensorflow.keras.layers import Dropout
model_2 = Sequential()
model_2.add(Dense(16,activation="relu",input_dim=X_train.shape[1]))  # Complete the code to define the number of neurons and activation function
model_2.add(Dropout(0.5)) # Complete the code to define the dropout rate
model_2.add(Dense(8,activation = "relu")) # Complete the code to define the number of neurons and activation function
model_2.add(Dense(4,activation = "relu")) # Complete the code to define the number of neurons and activation function
model_2.add(Dense(1,activation="sigmoid")) # Complete the code to define the number of neurons in the output layer

# %%
model_2.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 833 (3.25 KB)
#  Trainable params: 833 (3.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.SGD()   # defining SGD as the optimizer to be used
# model_2.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
# model_2.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
model_2.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_2.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_2.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs)
end=time.time()
# Out:
# Epoch 1/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - Recall: 0.0000e+00 - loss: 0.2549 - val_Recall: 0.0000e+00 - val_loss: 0.1687
# Epoch 2/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.0000e+00 - loss: 0.1936 - val_Recall: 0.0000e+00 - val_loss: 0.1493
# Epoch 3/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.0000e+00 - loss: 0.1723 - val_Recall: 0.0000e+00 - val_loss: 0.1376
# Epoch 4/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.0000e+00 - loss: 0.1638 - val_Recall: 0.0000e+00 - val_loss: 0.1300
# Epoch 5/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.0000e+00 - loss: 0.1530 - val_Recall: 0.0000e+00 - val_loss: 0.1268
# Epoch 6/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.0000e+00 - loss: 0.1493 - val_Recall: 0.0000e+00 - val_loss: 0.1225
# Epoch 7/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.0000e+00 - loss: 0.1441 - val_Recall: 0.0000e+00 - val_loss: 0.1186
# Epoch 8/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.0000e+00 - loss: 0.1422 - val_Recall: 0.0000e+00 - val_loss: 0.1163
# Epoch 9/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.0023 - loss: 0.1390 - val_Recall: 0.0000e+00 - val_loss: 0.1145
# Epoch 10/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.0169 - loss: 0.1342 - val_Recall: 0.0000e+00 - val_loss: 0.1128
# Epoch 11/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.0800 - loss: 0.1319 - val_Recall: 0.0450 - val_loss: 0.1116
# Epoch 12/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.1723 - loss: 0.1301 - val_Recall: 0.2072 - val_loss: 0.1086
# Epoch 13/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.2613 - loss: 0.1282 - val_Recall: 0.3649 - val_loss: 0.1030
# Epoch 14/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.3288 - loss: 0.1238 - val_Recall: 0.4730 - val_loss: 0.1003
# Epoch 15/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.3491 - loss: 0.1251 - val_Recall: 0.5090 - val_loss: 0.0986
# Epoch 16/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.3705 - loss: 0.1201 - val_Recall: 0.5541 - val_loss: 0.0959
# Epoch 17/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.4155 - loss: 0.1172 - val_Recall: 0.5901 - val_loss: 0.0920
# Epoch 18/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.3941 - loss: 0.1174 - val_Recall: 0.5946 - val_loss: 0.0901
# Epoch 19/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.4358 - loss: 0.1128 - val_Recall: 0.6126 - val_loss: 0.0892
# Epoch 20/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.4550 - loss: 0.1085 - val_Recall: 0.6171 - val_loss: 0.0862
# Epoch 21/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.4685 - loss: 0.1082 - val_Recall: 0.6667 - val_loss: 0.0861
# Epoch 22/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.4696 - loss: 0.1080 - val_Recall: 0.6622 - val_loss: 0.0842
# Epoch 23/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.4505 - loss: 0.1080 - val_Recall: 0.6757 - val_loss: 0.0846
# Epoch 24/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.4842 - loss: 0.1053 - val_Recall: 0.6757 - val_loss: 0.0812
# Epoch 25/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.4820 - loss: 0.1069 - val_Recall: 0.6982 - val_loss: 0.0840
# Epoch 26/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.4831 - loss: 0.1071 - val_Recall: 0.6892 - val_loss: 0.0830
# Epoch 27/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.4977 - loss: 0.1077 - val_Recall: 0.6712 - val_loss: 0.0814
# Epoch 28/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.4752 - loss: 0.1040 - val_Recall: 0.6802 - val_loss: 0.0813
# Epoch 29/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.4741 - loss: 0.1050 - val_Recall: 0.6712 - val_loss: 0.0830
# Epoch 30/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.5090 - loss: 0.0994 - val_Recall: 0.6712 - val_loss: 0.0810
# Epoch 31/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.5158 - loss: 0.1021 - val_Recall: 0.6802 - val_loss: 0.0818
# Epoch 32/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.4955 - loss: 0.1008 - val_Recall: 0.6757 - val_loss: 0.0798
# Epoch 33/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.5056 - loss: 0.0975 - val_Recall: 0.6802 - val_loss: 0.0774
# Epoch 34/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.4921 - loss: 0.1006 - val_Recall: 0.6892 - val_loss: 0.0803
# Epoch 35/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - Recall: 0.5079 - loss: 0.1005 - val_Recall: 0.6802 - val_loss: 0.0826
# Epoch 36/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.5011 - loss: 0.1012 - val_Recall: 0.6712 - val_loss: 0.0802
# Epoch 37/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - Recall: 0.4910 - loss: 0.1025 - val_Recall: 0.6847 - val_loss: 0.0844
# Epoch 38/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.4651 - loss: 0.1017 - val_Recall: 0.6757 - val_loss: 0.0827
# Epoch 39/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.4854 - loss: 0.1008 - val_Recall: 0.6847 - val_loss: 0.0807
# Epoch 40/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.4944 - loss: 0.0974 - val_Recall: 0.6892 - val_loss: 0.0851
# Epoch 41/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - Recall: 0.4651 - loss: 0.1018 - val_Recall: 0.6847 - val_loss: 0.0813
# Epoch 42/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.4876 - loss: 0.0984 - val_Recall: 0.7027 - val_loss: 0.0849
# Epoch 43/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.5011 - loss: 0.0971 - val_Recall: 0.7072 - val_loss: 0.0819
# Epoch 44/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.4932 - loss: 0.0966 - val_Recall: 0.6982 - val_loss: 0.0796
# Epoch 45/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.4775 - loss: 0.0988 - val_Recall: 0.6937 - val_loss: 0.0800
# Epoch 46/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.4865 - loss: 0.0973 - val_Recall: 0.7117 - val_loss: 0.0849
# Epoch 47/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.5158 - loss: 0.0946 - val_Recall: 0.7162 - val_loss: 0.0844
# Epoch 48/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.5011 - loss: 0.0960 - val_Recall: 0.6892 - val_loss: 0.0800
# Epoch 49/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.5101 - loss: 0.0939 - val_Recall: 0.6982 - val_loss: 0.0830
# Epoch 50/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.5023 - loss: 0.0937 - val_Recall: 0.6982 - val_loss: 0.0782

# %%
print("Time taken in seconds ",end-start)
# Out:
# Time taken in seconds  92.39152383804321

# %%
plot(history,'loss')

# %% [markdown]
# Lets check the model performance of model_2 on training and validation data respectively.

# %%
model_2_train_perf = model_performance_classification(model_2,X_train,y_train)
model_2_train_perf
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0  0.981625  0.839229   0.983387   0.89718

# %%
model_2_val_perf = model_performance_classification(model_2,X_val,y_val)
model_2_val_perf
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0     0.981  0.847908   0.963828  0.896564

# %%
y_train_pred_2 = model_2.predict(X_train)
y_val_pred_2 = model_2.predict(X_val)
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# Lets check the classification report of model_2 on training and validation data respectively.

# %%
print("Classification Report - Train data Model_2", end="\n\n")
cr_train_model_2 = classification_report(y_train,y_train_pred_2 > 0.5)
print(cr_train_model_2)
# Out:
# Classification Report - Train data Model_2
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99     15112
#          1.0       0.99      0.68      0.80       888
#
#     accuracy                           0.98     16000
#    macro avg       0.98      0.84      0.90     16000
# weighted avg       0.98      0.98      0.98     16000

# %%
print("Classification Report - Validation data Model_2", end="\n\n")
cr_val_model_2 = classification_report(y_val , y_val_pred_2 > 0.5)
print(cr_val_model_2)
# Out:
# Classification Report - Validation data Model_2
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      3778
#          1.0       0.95      0.70      0.80       222
#
#     accuracy                           0.98      4000
#    macro avg       0.96      0.85      0.90      4000
# weighted avg       0.98      0.98      0.98      4000

# %% [markdown]
# ## Model 3

# %% [markdown]
# As we have are dealing with an imbalance in class distribution, we should also be using class weights to allow the model to give proportionally more importance to the minority class.

# %%
# Calculate class weights for imbalanced dataset
cw = (y_train.shape[0]) / np.bincount(y_train.astype(int)) # Convert y_train to integers

# Create a dictionary mapping class indices to their respective class weights
cw_dict = {}
for i in range(cw.shape[0]):
    cw_dict[i] = cw[i]

cw_dict
# Out:
# {0: np.float64(1.0587612493382743), 1: np.float64(18.01801801801802)}

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
model_3 = Sequential()
model_3.add(Dense(16,activation="relu",input_dim=X_train.shape[1])) # Complete the code to define the number of neurons and activation function
model_3.add(Dropout(0.5)) # Complete the code to define the dropout rate
model_3.add(Dense(8,activation="relu")) # Complete the code to define the number of neurons and activation function
model_3.add(Dense(4, activation = "relu")) # Complete the code to define the number of neurons and activation function
model_3.add(Dense(1,activation="sigmoid")) # Complete the code to define the number of neurons in the output layer

# %%
model_3.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 833 (3.25 KB)
#  Trainable params: 833 (3.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.SGD()   # defining SGD as the optimizer to be used
# model_3.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
# model_3.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
model_3.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_3.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_3.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs,class_weight=cw_dict)
end=time.time()
# Out:
# Epoch 1/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - Recall: 0.7646 - loss: 1.0603 - val_Recall: 0.8423 - val_loss: 0.3757
# Epoch 2/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7680 - loss: 0.7871 - val_Recall: 0.8468 - val_loss: 0.2597
# Epoch 3/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7804 - loss: 0.7027 - val_Recall: 0.8784 - val_loss: 0.2329
# Epoch 4/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7905 - loss: 0.6731 - val_Recall: 0.8649 - val_loss: 0.2071
# Epoch 5/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8119 - loss: 0.6457 - val_Recall: 0.8649 - val_loss: 0.2546
# Epoch 6/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8356 - loss: 0.6086 - val_Recall: 0.8649 - val_loss: 0.1845
# Epoch 7/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8300 - loss: 0.6138 - val_Recall: 0.8649 - val_loss: 0.1939
# Epoch 8/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8412 - loss: 0.5679 - val_Recall: 0.8739 - val_loss: 0.1845
# Epoch 9/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8457 - loss: 0.5723 - val_Recall: 0.8604 - val_loss: 0.1945
# Epoch 10/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8266 - loss: 0.5828 - val_Recall: 0.8604 - val_loss: 0.2060
# Epoch 11/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8311 - loss: 0.5846 - val_Recall: 0.8604 - val_loss: 0.2046
# Epoch 12/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8367 - loss: 0.5679 - val_Recall: 0.8784 - val_loss: 0.1891
# Epoch 13/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8547 - loss: 0.5336 - val_Recall: 0.8739 - val_loss: 0.1860
# Epoch 14/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8401 - loss: 0.5381 - val_Recall: 0.8604 - val_loss: 0.1638
# Epoch 15/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8367 - loss: 0.5462 - val_Recall: 0.8694 - val_loss: 0.1778
# Epoch 16/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8502 - loss: 0.5406 - val_Recall: 0.8784 - val_loss: 0.1800
# Epoch 17/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8435 - loss: 0.5385 - val_Recall: 0.8784 - val_loss: 0.1864
# Epoch 18/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8468 - loss: 0.5257 - val_Recall: 0.8514 - val_loss: 0.1659
# Epoch 19/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8480 - loss: 0.5219 - val_Recall: 0.8559 - val_loss: 0.1830
# Epoch 20/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8435 - loss: 0.5290 - val_Recall: 0.8649 - val_loss: 0.1706
# Epoch 21/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8446 - loss: 0.5247 - val_Recall: 0.8739 - val_loss: 0.1716
# Epoch 22/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8435 - loss: 0.5188 - val_Recall: 0.8604 - val_loss: 0.1593
# Epoch 23/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8491 - loss: 0.5206 - val_Recall: 0.8649 - val_loss: 0.1771
# Epoch 24/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8446 - loss: 0.5272 - val_Recall: 0.8649 - val_loss: 0.1746
# Epoch 25/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8536 - loss: 0.5145 - val_Recall: 0.8649 - val_loss: 0.1713
# Epoch 26/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8547 - loss: 0.5195 - val_Recall: 0.8378 - val_loss: 0.1513
# Epoch 27/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8480 - loss: 0.5234 - val_Recall: 0.8604 - val_loss: 0.1609
# Epoch 28/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8457 - loss: 0.5135 - val_Recall: 0.8694 - val_loss: 0.1664
# Epoch 29/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8457 - loss: 0.5276 - val_Recall: 0.8649 - val_loss: 0.1613
# Epoch 30/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8401 - loss: 0.5245 - val_Recall: 0.8604 - val_loss: 0.1720
# Epoch 31/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8592 - loss: 0.4883 - val_Recall: 0.8559 - val_loss: 0.1627
# Epoch 32/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8525 - loss: 0.5070 - val_Recall: 0.8649 - val_loss: 0.1713
# Epoch 33/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8480 - loss: 0.5248 - val_Recall: 0.8649 - val_loss: 0.1563
# Epoch 34/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8525 - loss: 0.5032 - val_Recall: 0.8739 - val_loss: 0.1710
# Epoch 35/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8592 - loss: 0.5019 - val_Recall: 0.8739 - val_loss: 0.1700
# Epoch 36/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8525 - loss: 0.5159 - val_Recall: 0.8559 - val_loss: 0.1593
# Epoch 37/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8514 - loss: 0.4977 - val_Recall: 0.8694 - val_loss: 0.1554
# Epoch 38/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8525 - loss: 0.5041 - val_Recall: 0.8468 - val_loss: 0.1507
# Epoch 39/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - Recall: 0.8581 - loss: 0.4741 - val_Recall: 0.8694 - val_loss: 0.1636
# Epoch 40/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8536 - loss: 0.5037 - val_Recall: 0.8649 - val_loss: 0.1599
# Epoch 41/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8649 - loss: 0.4838 - val_Recall: 0.8604 - val_loss: 0.1481
# Epoch 42/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8525 - loss: 0.5046 - val_Recall: 0.8649 - val_loss: 0.1613
# Epoch 43/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8514 - loss: 0.5073 - val_Recall: 0.8559 - val_loss: 0.1581
# Epoch 44/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8570 - loss: 0.5003 - val_Recall: 0.8604 - val_loss: 0.1489
# Epoch 45/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8514 - loss: 0.5148 - val_Recall: 0.8649 - val_loss: 0.1566
# Epoch 46/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8547 - loss: 0.4927 - val_Recall: 0.8514 - val_loss: 0.1481
# Epoch 47/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8536 - loss: 0.4994 - val_Recall: 0.8604 - val_loss: 0.1483
# Epoch 48/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8525 - loss: 0.4991 - val_Recall: 0.8333 - val_loss: 0.1469
# Epoch 49/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8457 - loss: 0.5059 - val_Recall: 0.8604 - val_loss: 0.1536
# Epoch 50/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8547 - loss: 0.5038 - val_Recall: 0.8604 - val_loss: 0.1515

# %%
print("Time taken in seconds ",end-start)
# Out:
# Time taken in seconds  89.55042338371277

# %%
plot(history,'loss')

# %% [markdown]
# Lets check the model performance of model_3 on training and validation data respectively.

# %%
model_3_train_perf = model_performance_classification(model_3,X_train,y_train)
model_3_train_perf
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0  0.985187  0.938101   0.923328  0.930569

# %%
model_3_val_perf = model_performance_classification(model_3,X_val,y_val)
model_3_val_perf
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0   0.98425  0.925945   0.924147  0.925044

# %%
y_train_pred_3 = model_3.predict(X_train)
y_val_pred_3 = model_3.predict(X_val)
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# Lets check the classification report of model_3 on training and validation data respectively.

# %%
print("Classification Report - Train data Model_3", end="\n\n")
cr_train_model_3 = classification_report(y_train,y_train_pred_3 > 0.5)
print(cr_train_model_3)
# Out:
# Classification Report - Train data Model_3
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99     15112
#          1.0       0.85      0.89      0.87       888
#
#     accuracy                           0.99     16000
#    macro avg       0.92      0.94      0.93     16000
# weighted avg       0.99      0.99      0.99     16000

# %%
print("Classification Report - Validation data Model_3", end="\n\n")
cr_val_model_3 = classification_report(y_val,y_val_pred_3 > 0.5)
print(cr_val_model_3)
# Out:
# Classification Report - Validation data Model_3
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      3778
#          1.0       0.86      0.86      0.86       222
#
#     accuracy                           0.98      4000
#    macro avg       0.92      0.93      0.93      4000
# weighted avg       0.98      0.98      0.98      4000

# %% [markdown]
# ## Model 4

# %% [markdown]
# Since we have used only SGD optimizer till now, let's use another kind of optimizer and observe its impact on the model performmance.

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
#Initializing the neural network
model_4 = Sequential()
model_4.add(Dense(16,activation="relu",input_dim=X_train.shape[1])) # Complete the code to define the number of neurons and activation function
model_4.add(Dense(8,activation="relu")) # Complete the code to define the number of neurons and activation function
model_4.add(Dense(1,activation="sigmoid")) # Complete the code to define the number of neurons in the output layer

# %%
model_4.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 801 (3.13 KB)
#  Trainable params: 801 (3.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.Adam()    # defining Adam as the optimizer to be used
# model_4.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
# model_4.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
model_4.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_4.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_4.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs)
end=time.time()
# Out:
# Epoch 1/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - Recall: 0.5101 - loss: 0.1331 - val_Recall: 0.6126 - val_loss: 0.0906
# Epoch 2/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.7050 - loss: 0.0774 - val_Recall: 0.7703 - val_loss: 0.0688
# Epoch 3/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.7995 - loss: 0.0611 - val_Recall: 0.8288 - val_loss: 0.0617
# Epoch 4/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8322 - loss: 0.0543 - val_Recall: 0.8198 - val_loss: 0.0590
# Epoch 5/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8412 - loss: 0.0503 - val_Recall: 0.8288 - val_loss: 0.0572
# Epoch 6/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8570 - loss: 0.0478 - val_Recall: 0.8333 - val_loss: 0.0571
# Epoch 7/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8581 - loss: 0.0450 - val_Recall: 0.8514 - val_loss: 0.0557
# Epoch 8/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8682 - loss: 0.0438 - val_Recall: 0.8468 - val_loss: 0.0557
# Epoch 9/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8649 - loss: 0.0424 - val_Recall: 0.8604 - val_loss: 0.0564
# Epoch 10/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8716 - loss: 0.0418 - val_Recall: 0.8468 - val_loss: 0.0566
# Epoch 11/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8739 - loss: 0.0407 - val_Recall: 0.8694 - val_loss: 0.0558
# Epoch 12/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8784 - loss: 0.0401 - val_Recall: 0.8559 - val_loss: 0.0562
# Epoch 13/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8840 - loss: 0.0399 - val_Recall: 0.8468 - val_loss: 0.0574
# Epoch 14/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8795 - loss: 0.0395 - val_Recall: 0.8604 - val_loss: 0.0575
# Epoch 15/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8829 - loss: 0.0390 - val_Recall: 0.8514 - val_loss: 0.0567
# Epoch 16/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8773 - loss: 0.0387 - val_Recall: 0.8604 - val_loss: 0.0567
# Epoch 17/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8885 - loss: 0.0379 - val_Recall: 0.8604 - val_loss: 0.0585
# Epoch 18/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8818 - loss: 0.0379 - val_Recall: 0.8604 - val_loss: 0.0578
# Epoch 19/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8908 - loss: 0.0379 - val_Recall: 0.8649 - val_loss: 0.0592
# Epoch 20/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8874 - loss: 0.0372 - val_Recall: 0.8649 - val_loss: 0.0578
# Epoch 21/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8840 - loss: 0.0369 - val_Recall: 0.8694 - val_loss: 0.0617
# Epoch 22/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8885 - loss: 0.0368 - val_Recall: 0.8739 - val_loss: 0.0577
# Epoch 23/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8896 - loss: 0.0363 - val_Recall: 0.8514 - val_loss: 0.0585
# Epoch 24/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8885 - loss: 0.0365 - val_Recall: 0.8604 - val_loss: 0.0584
# Epoch 25/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8964 - loss: 0.0361 - val_Recall: 0.8604 - val_loss: 0.0584
# Epoch 26/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8896 - loss: 0.0355 - val_Recall: 0.8604 - val_loss: 0.0596
# Epoch 27/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8930 - loss: 0.0359 - val_Recall: 0.8559 - val_loss: 0.0610
# Epoch 28/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8908 - loss: 0.0354 - val_Recall: 0.8559 - val_loss: 0.0591
# Epoch 29/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8953 - loss: 0.0349 - val_Recall: 0.8604 - val_loss: 0.0608
# Epoch 30/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8885 - loss: 0.0352 - val_Recall: 0.8694 - val_loss: 0.0608
# Epoch 31/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8941 - loss: 0.0351 - val_Recall: 0.8559 - val_loss: 0.0601
# Epoch 32/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8964 - loss: 0.0345 - val_Recall: 0.8604 - val_loss: 0.0609
# Epoch 33/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8986 - loss: 0.0341 - val_Recall: 0.8559 - val_loss: 0.0612
# Epoch 34/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8930 - loss: 0.0342 - val_Recall: 0.8649 - val_loss: 0.0616
# Epoch 35/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8986 - loss: 0.0335 - val_Recall: 0.8604 - val_loss: 0.0618
# Epoch 36/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8998 - loss: 0.0340 - val_Recall: 0.8378 - val_loss: 0.0637
# Epoch 37/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8953 - loss: 0.0338 - val_Recall: 0.8649 - val_loss: 0.0606
# Epoch 38/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8986 - loss: 0.0337 - val_Recall: 0.8694 - val_loss: 0.0606
# Epoch 39/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8908 - loss: 0.0334 - val_Recall: 0.8604 - val_loss: 0.0628
# Epoch 40/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8975 - loss: 0.0331 - val_Recall: 0.8514 - val_loss: 0.0643
# Epoch 41/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8941 - loss: 0.0336 - val_Recall: 0.8604 - val_loss: 0.0623
# Epoch 42/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8964 - loss: 0.0331 - val_Recall: 0.8694 - val_loss: 0.0625
# Epoch 43/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8930 - loss: 0.0330 - val_Recall: 0.8559 - val_loss: 0.0626
# Epoch 44/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8953 - loss: 0.0333 - val_Recall: 0.8649 - val_loss: 0.0630
# Epoch 45/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8930 - loss: 0.0329 - val_Recall: 0.8694 - val_loss: 0.0634
# Epoch 46/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8975 - loss: 0.0323 - val_Recall: 0.8604 - val_loss: 0.0624
# Epoch 47/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8953 - loss: 0.0328 - val_Recall: 0.8694 - val_loss: 0.0620
# Epoch 48/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8953 - loss: 0.0330 - val_Recall: 0.8649 - val_loss: 0.0636
# Epoch 49/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8964 - loss: 0.0327 - val_Recall: 0.8604 - val_loss: 0.0630
# Epoch 50/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8953 - loss: 0.0323 - val_Recall: 0.8649 - val_loss: 0.0616

# %%
print("Time taken in seconds ",end-start)
# Out:
# Time taken in seconds  85.27734804153442

# %%
plot(history,'loss')

# %% [markdown]
# Lets check the model performance ofr model_4 on training and validation data respectively

# %%
model_4_train_perf = model_performance_classification(model_4,X_train,y_train)
model_4_train_perf
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0  0.994125  0.948662   0.995132  0.970606

# %%
model_4_val_perf = model_performance_classification(model_4,X_val,y_val)
model_4_val_perf
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0    0.9915  0.931903   0.985853  0.957088

# %%
y_train_pred_4 = model_4.predict(X_train)
y_val_pred_4 = model_4.predict(X_val)
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# Lets check the classification report of model_4 on raining and validation data respectively.

# %%
print("Classification Report - Train data Model_4", end="\n\n")
cr_train_model_4 = classification_report(y_train,y_train_pred_4 > 0.5)
print(cr_train_model_4)
# Out:
# Classification Report - Train data Model_4
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00     15112
#          1.0       1.00      0.90      0.94       888
#
#     accuracy                           0.99     16000
#    macro avg       1.00      0.95      0.97     16000
# weighted avg       0.99      0.99      0.99     16000

# %%
print("Classification Report - Validation data Model_4", end="\n\n")
cr_val_model_4 = classification_report(y_val,y_val_pred_4 > 0.5)
print(cr_val_model_4)
# Out:
# Classification Report - Validation data Model_4
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      3778
#          1.0       0.98      0.86      0.92       222
#
#     accuracy                           0.99      4000
#    macro avg       0.99      0.93      0.96      4000
# weighted avg       0.99      0.99      0.99      4000

# %% [markdown]
# ## Model 5

# %% [markdown]
# This time we will add more layers and dropout while using a different optimizer.

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
#Initializing the neural network
from tensorflow.keras.layers import Dropout
model_5 = Sequential()
model_5.add(Dense(32,activation="relu",input_dim=X_train.shape[1])) # Complete the code to define the number of neurons and activation function
model_5.add(Dropout(0.5)) #Complete the code to define the dropout rate
model_5.add(Dense(16,activation="relu")) # Complete the code to define the number of neurons and activation function
model_5.add(Dense(8, activation = "relu")) # Complete the code to define the number of neurons and activation function
model_5.add(Dense(1,activation="sigmoid")) # Complete the code to define the number of neurons and activation function

# %%
model_5.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │         1,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,985 (7.75 KB)
#  Trainable params: 1,985 (7.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.Adam()    # defining Adam as the optimizer to be used
# model_5.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
# model_5.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
model_5.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_5.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_5.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs)
end=time.time()
# Out:
# Epoch 1/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - Recall: 0.2038 - loss: 0.1910 - val_Recall: 0.4775 - val_loss: 0.1029
# Epoch 2/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.4595 - loss: 0.1198 - val_Recall: 0.6396 - val_loss: 0.0845
# Epoch 3/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.5957 - loss: 0.0984 - val_Recall: 0.7252 - val_loss: 0.0741
# Epoch 4/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - Recall: 0.6160 - loss: 0.0925 - val_Recall: 0.7928 - val_loss: 0.0688
# Epoch 5/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.6791 - loss: 0.0829 - val_Recall: 0.7748 - val_loss: 0.0718
# Epoch 6/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.6926 - loss: 0.0815 - val_Recall: 0.7838 - val_loss: 0.0649
# Epoch 7/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.7095 - loss: 0.0760 - val_Recall: 0.7793 - val_loss: 0.0650
# Epoch 8/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7252 - loss: 0.0754 - val_Recall: 0.7613 - val_loss: 0.0654
# Epoch 9/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7286 - loss: 0.0734 - val_Recall: 0.7928 - val_loss: 0.0627
# Epoch 10/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7140 - loss: 0.0734 - val_Recall: 0.8108 - val_loss: 0.0636
# Epoch 11/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7432 - loss: 0.0686 - val_Recall: 0.7658 - val_loss: 0.0634
# Epoch 12/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.7534 - loss: 0.0669 - val_Recall: 0.8153 - val_loss: 0.0603
# Epoch 13/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7489 - loss: 0.0662 - val_Recall: 0.8198 - val_loss: 0.0598
# Epoch 14/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7725 - loss: 0.0650 - val_Recall: 0.8018 - val_loss: 0.0659
# Epoch 15/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.7849 - loss: 0.0636 - val_Recall: 0.7883 - val_loss: 0.0609
# Epoch 16/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.7725 - loss: 0.0624 - val_Recall: 0.8108 - val_loss: 0.0596
# Epoch 17/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.7815 - loss: 0.0619 - val_Recall: 0.8288 - val_loss: 0.0607
# Epoch 18/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7849 - loss: 0.0630 - val_Recall: 0.8108 - val_loss: 0.0603
# Epoch 19/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7838 - loss: 0.0619 - val_Recall: 0.8243 - val_loss: 0.0603
# Epoch 20/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7860 - loss: 0.0632 - val_Recall: 0.8018 - val_loss: 0.0613
# Epoch 21/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.7905 - loss: 0.0594 - val_Recall: 0.7973 - val_loss: 0.0611
# Epoch 22/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.7860 - loss: 0.0601 - val_Recall: 0.8063 - val_loss: 0.0591
# Epoch 23/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.7894 - loss: 0.0606 - val_Recall: 0.8288 - val_loss: 0.0597
# Epoch 24/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8007 - loss: 0.0566 - val_Recall: 0.8108 - val_loss: 0.0588
# Epoch 25/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8018 - loss: 0.0585 - val_Recall: 0.8063 - val_loss: 0.0598
# Epoch 26/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7917 - loss: 0.0596 - val_Recall: 0.8243 - val_loss: 0.0593
# Epoch 27/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8153 - loss: 0.0557 - val_Recall: 0.8153 - val_loss: 0.0596
# Epoch 28/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7984 - loss: 0.0592 - val_Recall: 0.8108 - val_loss: 0.0610
# Epoch 29/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8018 - loss: 0.0566 - val_Recall: 0.8288 - val_loss: 0.0586
# Epoch 30/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8041 - loss: 0.0566 - val_Recall: 0.8198 - val_loss: 0.0590
# Epoch 31/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7984 - loss: 0.0576 - val_Recall: 0.8063 - val_loss: 0.0612
# Epoch 32/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.7962 - loss: 0.0583 - val_Recall: 0.8153 - val_loss: 0.0579
# Epoch 33/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8097 - loss: 0.0565 - val_Recall: 0.8018 - val_loss: 0.0577
# Epoch 34/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.7973 - loss: 0.0579 - val_Recall: 0.8108 - val_loss: 0.0582
# Epoch 35/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8029 - loss: 0.0566 - val_Recall: 0.8243 - val_loss: 0.0575
# Epoch 36/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8086 - loss: 0.0559 - val_Recall: 0.8243 - val_loss: 0.0577
# Epoch 37/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - Recall: 0.8007 - loss: 0.0550 - val_Recall: 0.8243 - val_loss: 0.0577
# Epoch 38/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8063 - loss: 0.0556 - val_Recall: 0.8378 - val_loss: 0.0563
# Epoch 39/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8142 - loss: 0.0546 - val_Recall: 0.8108 - val_loss: 0.0575
# Epoch 40/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8142 - loss: 0.0536 - val_Recall: 0.7838 - val_loss: 0.0583
# Epoch 41/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8063 - loss: 0.0571 - val_Recall: 0.8153 - val_loss: 0.0564
# Epoch 42/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.7950 - loss: 0.0578 - val_Recall: 0.8243 - val_loss: 0.0549
# Epoch 43/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8097 - loss: 0.0540 - val_Recall: 0.8288 - val_loss: 0.0544
# Epoch 44/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8142 - loss: 0.0527 - val_Recall: 0.8378 - val_loss: 0.0581
# Epoch 45/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8142 - loss: 0.0524 - val_Recall: 0.8288 - val_loss: 0.0568
# Epoch 46/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8131 - loss: 0.0545 - val_Recall: 0.8243 - val_loss: 0.0565
# Epoch 47/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8243 - loss: 0.0520 - val_Recall: 0.8063 - val_loss: 0.0586
# Epoch 48/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8221 - loss: 0.0535 - val_Recall: 0.8243 - val_loss: 0.0564
# Epoch 49/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8131 - loss: 0.0541 - val_Recall: 0.8108 - val_loss: 0.0575
# Epoch 50/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8142 - loss: 0.0523 - val_Recall: 0.8018 - val_loss: 0.0582

# %%
print("Time taken in seconds ",end-start)
# Out:
# Time taken in seconds  87.8034234046936

# %%
plot(history,'loss')

# %% [markdown]
# Lets check the model performance of model_5 on the training and validation data.

# %%
model_5_train_perf = model_performance_classification(model_5,X_train,y_train)
model_5_train_perf
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0  0.989688  0.908155   0.993288  0.946201

# %%
model_5_val_perf = model_performance_classification(model_5,X_val,y_val)
model_5_val_perf
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0    0.9885  0.900636   0.988685  0.939759

# %%
y_train_pred_5 = model_5.predict(X_train)
y_val_pred_5 = model_5.predict(X_val)
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# Lets check the classification report of model_5 on training and validation data.

# %%
print("Classification Report - Train data Model_2", end="\n\n")
cr_train_model_5 = classification_report(y_train,y_train_pred_5 > 0.5)
print(cr_train_model_5)
# Out:
# Classification Report - Train data Model_2
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99     15112
#          1.0       1.00      0.82      0.90       888
#
#     accuracy                           0.99     16000
#    macro avg       0.99      0.91      0.95     16000
# weighted avg       0.99      0.99      0.99     16000

# %%
print("Classification Report - Validation data Model_2", end="\n\n")
cr_val_model_5 = classification_report(y_val,y_val_pred_5 > 0.5)
print(cr_val_model_5)
# Out:
# Classification Report - Validation data Model_2
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      3778
#          1.0       0.99      0.80      0.89       222
#
#     accuracy                           0.99      4000
#    macro avg       0.99      0.90      0.94      4000
# weighted avg       0.99      0.99      0.99      4000

# %% [markdown]
# ## Model 6

# %% [markdown]
# Let's see how does the model performance change when the model gives higher importance to the minority class

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
model_6 = Sequential()
model_6.add(Dense(32,activation="relu",input_dim=X_train.shape[1])) # Complete the code to define the number of neurons and activation function
model_6.add(Dropout(0.5)) # Complete the code to define the dropout rate
model_6.add(Dense(16,activation="relu")) # Complete the code to define the number of neurons and activation function
model_6.add(Dense(8, activation = "relu")) # Complete the code to define the number of neurons and activation function
model_6.add(Dense(1,activation="sigmoid")) # Complete the code to define the number of neurons in the output layer

# %%
model_6.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │         1,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,985 (7.75 KB)
#  Trainable params: 1,985 (7.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.SGD()
# model_6.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
# model_6.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
model_6.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_6.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_3.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs,class_weight= cw_dict ) # Complete the code such that the model is biased towards the minority class
end=time.time()
# Out:
# Epoch 1/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8491 - loss: 0.5081 - val_Recall: 0.8423 - val_loss: 0.1498
# Epoch 2/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8547 - loss: 0.4871 - val_Recall: 0.8649 - val_loss: 0.1490
# Epoch 3/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8705 - loss: 0.4679 - val_Recall: 0.8468 - val_loss: 0.1444
# Epoch 4/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8649 - loss: 0.4818 - val_Recall: 0.8514 - val_loss: 0.1553
# Epoch 5/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8435 - loss: 0.5075 - val_Recall: 0.8559 - val_loss: 0.1528
# Epoch 6/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8446 - loss: 0.5118 - val_Recall: 0.8649 - val_loss: 0.1571
# Epoch 7/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8615 - loss: 0.4820 - val_Recall: 0.8559 - val_loss: 0.1532
# Epoch 8/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8514 - loss: 0.4919 - val_Recall: 0.8784 - val_loss: 0.1616
# Epoch 9/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8626 - loss: 0.4829 - val_Recall: 0.8559 - val_loss: 0.1441
# Epoch 10/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8502 - loss: 0.4967 - val_Recall: 0.8559 - val_loss: 0.1463
# Epoch 11/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8604 - loss: 0.4841 - val_Recall: 0.8649 - val_loss: 0.1479
# Epoch 12/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8525 - loss: 0.4962 - val_Recall: 0.8649 - val_loss: 0.1463
# Epoch 13/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8525 - loss: 0.4965 - val_Recall: 0.8784 - val_loss: 0.1575
# Epoch 14/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8525 - loss: 0.4936 - val_Recall: 0.8649 - val_loss: 0.1503
# Epoch 15/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8592 - loss: 0.4872 - val_Recall: 0.8739 - val_loss: 0.1525
# Epoch 16/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8502 - loss: 0.4925 - val_Recall: 0.8559 - val_loss: 0.1521
# Epoch 17/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8491 - loss: 0.5007 - val_Recall: 0.8694 - val_loss: 0.1498
# Epoch 18/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8457 - loss: 0.5062 - val_Recall: 0.8649 - val_loss: 0.1559
# Epoch 19/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8592 - loss: 0.4912 - val_Recall: 0.8514 - val_loss: 0.1539
# Epoch 20/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8514 - loss: 0.4983 - val_Recall: 0.8694 - val_loss: 0.1590
# Epoch 21/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8592 - loss: 0.4861 - val_Recall: 0.8559 - val_loss: 0.1481
# Epoch 22/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8491 - loss: 0.5002 - val_Recall: 0.8514 - val_loss: 0.1509
# Epoch 23/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8514 - loss: 0.4957 - val_Recall: 0.8604 - val_loss: 0.1538
# Epoch 24/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8435 - loss: 0.5002 - val_Recall: 0.8604 - val_loss: 0.1520
# Epoch 25/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - Recall: 0.8615 - loss: 0.4769 - val_Recall: 0.8694 - val_loss: 0.1552
# Epoch 26/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8390 - loss: 0.5115 - val_Recall: 0.8649 - val_loss: 0.1499
# Epoch 27/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8570 - loss: 0.4759 - val_Recall: 0.8604 - val_loss: 0.1434
# Epoch 28/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8604 - loss: 0.4838 - val_Recall: 0.8423 - val_loss: 0.1462
# Epoch 29/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8604 - loss: 0.4833 - val_Recall: 0.8559 - val_loss: 0.1439
# Epoch 30/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8570 - loss: 0.4930 - val_Recall: 0.8694 - val_loss: 0.1523
# Epoch 31/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8446 - loss: 0.4987 - val_Recall: 0.8739 - val_loss: 0.1501
# Epoch 32/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8457 - loss: 0.4972 - val_Recall: 0.8694 - val_loss: 0.1496
# Epoch 33/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8412 - loss: 0.5180 - val_Recall: 0.8694 - val_loss: 0.1580
# Epoch 34/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8525 - loss: 0.4918 - val_Recall: 0.8649 - val_loss: 0.1494
# Epoch 35/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8514 - loss: 0.4899 - val_Recall: 0.8784 - val_loss: 0.1538
# Epoch 36/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8660 - loss: 0.4796 - val_Recall: 0.8604 - val_loss: 0.1396
# Epoch 37/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - Recall: 0.8502 - loss: 0.4862 - val_Recall: 0.8694 - val_loss: 0.1525
# Epoch 38/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8694 - loss: 0.4800 - val_Recall: 0.8694 - val_loss: 0.1480
# Epoch 39/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8525 - loss: 0.5094 - val_Recall: 0.8694 - val_loss: 0.1478
# Epoch 40/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8660 - loss: 0.4847 - val_Recall: 0.8604 - val_loss: 0.1515
# Epoch 41/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8581 - loss: 0.4792 - val_Recall: 0.8694 - val_loss: 0.1400
# Epoch 42/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8615 - loss: 0.4788 - val_Recall: 0.8649 - val_loss: 0.1516
# Epoch 43/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8649 - loss: 0.4718 - val_Recall: 0.8649 - val_loss: 0.1423
# Epoch 44/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8547 - loss: 0.4869 - val_Recall: 0.8649 - val_loss: 0.1400
# Epoch 45/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8502 - loss: 0.4968 - val_Recall: 0.8649 - val_loss: 0.1604
# Epoch 46/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8536 - loss: 0.4937 - val_Recall: 0.8559 - val_loss: 0.1541
# Epoch 47/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8559 - loss: 0.4863 - val_Recall: 0.8604 - val_loss: 0.1534
# Epoch 48/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8637 - loss: 0.4849 - val_Recall: 0.8649 - val_loss: 0.1463
# Epoch 49/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8626 - loss: 0.4883 - val_Recall: 0.8514 - val_loss: 0.1508
# Epoch 50/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8502 - loss: 0.4889 - val_Recall: 0.8649 - val_loss: 0.1501

# %%
print("Time taken in seconds ",end-start)
# Out:
# Time taken in seconds  83.0263249874115

# %%
plot(history,'loss')

# %% [markdown]
# Lets check the model performance of model_6 on training and validation data.

# %%
model_6_train_perf = model_performance_classification(model_6,X_train,y_train)
model_6_train_perf
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0  0.173687  0.429012   0.470764  0.166291

# %%
model_6_val_perf = model_performance_classification(model_6,X_val,y_val)
model_6_val_perf
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0   0.18025  0.445206   0.477865  0.172342

# %%
y_train_pred_6 = model_6.predict(X_train)
y_val_pred_6 = model_6.predict(X_val)
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# Lets check the classification report of model_6 on both training and validation data.

# %%
print("Classification Report - Train data Model_3", end="\n\n")
cr_train_model_6 = classification_report(y_train,y_train_pred_6 > 0.5)
print(cr_train_model_6)
# Out:
# Classification Report - Train data Model_3
#
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.14      0.24     15112
#          1.0       0.05      0.72      0.09       888
#
#     accuracy                           0.17     16000
#    macro avg       0.47      0.43      0.17     16000
# weighted avg       0.85      0.17      0.24     16000

# %%
print("Classification Report - Validation data Model_3", end="\n\n")
cr_val_model_6 = classification_report(y_val,y_val_pred_6 > 0.5)
print(cr_val_model_6)
# Out:
# Classification Report - Validation data Model_3
#
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.15      0.25      3778
#          1.0       0.05      0.74      0.09       222
#
#     accuracy                           0.18      4000
#    macro avg       0.48      0.45      0.17      4000
# weighted avg       0.86      0.18      0.24      4000

# %% [markdown]
# # **Model Performance Comparison and Final Model Selection**

# %% [markdown]
# Now, in order to select the final model, we will compare the performances of all the models for the training and test sets.

# %% [markdown]
# **Training Performance Comparison**

# %%
# training performance comparison

models_train_comp_df = pd.concat(
    [
        model_0_train_perf.T,
        model_1_train_perf.T,
        model_2_train_perf.T,
        model_3_train_perf.T,
        model_4_train_perf.T,
        model_5_train_perf.T,
        model_6_train_perf.T

    ],
    axis=1,
)
models_train_comp_df.columns = [
    "Model 0",
    "Model 1",
    "Model 2",
    "Model 3",
    "Model 4",
    "Model 5",
    "Model 6"
]
print("Training set performance comparison:")
models_train_comp_df
# Out:
# Training set performance comparison:
#             Model 0   Model 1   Model 2   Model 3   Model 4   Model 5  \
# Accuracy   0.988187  0.991250  0.981625  0.985187  0.994125  0.989688
# Recall     0.906831  0.930711  0.839229  0.938101  0.948662  0.908155
# Precision  0.977934  0.984511  0.983387  0.923328  0.995132  0.993288
# F1 Score   0.939160  0.955826  0.897180  0.930569  0.970606  0.946201
#
#             Model 6
# Accuracy   0.173687
# Recall     0.429012
# Precision  0.470764
# F1 Score   0.166291

# %% [markdown]
# **Validation Performance Comparison**

# %%
# Validation performance comparison

models_val_comp_df = pd.concat(
    [
        model_0_val_perf.T,
        model_1_val_perf.T,
        model_2_val_perf.T,
        model_3_val_perf.T,
        model_4_val_perf.T,
        model_5_val_perf.T,
        model_6_val_perf.T

    ],
    axis=1,
)
models_val_comp_df.columns = [
    "Model 0",
    "Model 1",
    "Model 2",
    "Model 3",
    "Model 4",
    "Model 5",
    "Model 6"
]
print("Validation set performance comparison:")
models_val_comp_df
# Out:
# Validation set performance comparison:
#             Model 0   Model 1   Model 2   Model 3   Model 4   Model 5  \
# Accuracy   0.986750  0.989500  0.981000  0.984250  0.991500  0.988500
# Recall     0.899710  0.916005  0.847908  0.925945  0.931903  0.900636
# Precision  0.970166  0.981986  0.963828  0.924147  0.985853  0.988685
# F1 Score   0.931717  0.946262  0.896564  0.925044  0.957088  0.939759
#
#             Model 6
# Accuracy   0.180250
# Recall     0.445206
# Precision  0.477865
# F1 Score   0.172342

# %% [markdown]
# **Checking the performance of the best model on the test set**

# %%
# best_model = model_0 ## Uncomment this line in case the best model is model_0
# best_model = model_1 ## Uncomment this line in case the best model is model_1
# best_model = model_2 ## Uncomment this line in case the best model is model_2
# best_model = model_3 ## Uncomment this line in case the best model is model_3
best_model = model_4 ## Uncomment this line in case the best model is model_4
# best_model = model_5 ## Uncomment this line in case the best model is model_5
# best_model = model_6 ## Uncomment this line in case the best model is model_6

# %%
# Test set performance for the best model
best_model_test_perf = model_performance_classification(best_model,X_test,y_test)
best_model_test_perf
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0    0.9892  0.920926   0.975209  0.946205

# %%
y_test_pred_best = best_model.predict(X_test)

cr_test_best_model = classification_report(y_test, y_test_pred_best>0.5) # Check the classification report of best model on test data.
print(cr_test_best_model)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      4718
#          1.0       0.96      0.84      0.90       282
#
#     accuracy                           0.99      5000
#    macro avg       0.98      0.92      0.95      5000
# weighted avg       0.99      0.99      0.99      5000

# %% [markdown]
# # **Actionable Insights and Recommendations**

# %% [markdown]
# - Write down actionable insights here

# %% [markdown]
# - Write down business recommendations here
